# %% [markdown]
# <a href="https://colab.research.google.com/github/arzuantor/Spam-Email-Detection/blob/main/Spam_Email_Detection_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Import Libraries

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
import re
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %% [markdown]
# #Load Dataset

# %%
df=pd.read_csv('spam.csv')

# %% [markdown]
# #See First 5 Data

# %%
df.head()
# Out:
#    Category                                            Message
# 0         0  Go until jurong point, crazy.. Available only ...
# 1         0                      Ok lar... Joking wif u oni...
# 2         1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3         0  U dun say so early hor... U c already then say...
# 4         0  Nah I don't think he goes to usf, he lives aro...

# %% [markdown]
# #Text-to-Numeric Label Encoding

# %%
le=LabelEncoder()

# %%
df['Category']=le.fit_transform(df['Category'])

# %%
df.head()
# Out:
#    Category                                            Message
# 0         0  Go until jurong point, crazy.. Available only ...
# 1         0                      Ok lar... Joking wif u oni...
# 2         1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3         0  U dun say so early hor... U c already then say...
# 4         0  Nah I don't think he goes to usf, he lives aro...

# %% [markdown]
# #Text Cleaning

# %%
def clean_text(text):
    text = text.lower()
    text = re.sub(r'[^a-zA-Z ]', '', text)
    return text
df['Message']=df['Message'].apply(clean_text)

# %%
df.head()
# Out:
#    Category                                            Message
# 0         0  go until jurong point crazy available only in ...
# 1         0                            ok lar joking wif u oni
# 2         1  free entry in  a wkly comp to win fa cup final...
# 3         0        u dun say so early hor u c already then say
# 4         0  nah i dont think he goes to usf he lives aroun...

# %% [markdown]
# #Subject Creating

# %%
vec=TfidfVectorizer()

# %% [markdown]
# # use vectorizer for the data

# %%
x=vec.fit_transform(df['Message'])
y=df['Category']

# %% [markdown]
# #check the data shape

# %%
print(X.shape)
# Out:
# (5572, 8605)

# %% [markdown]
# #use train test split

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=.2,random_state=42)

# %% [markdown]
# #create logistic regression subject

# %%
model=LogisticRegression()

# %% [markdown]
# #fit the model

# %%
model.fit(xtrain, ytrain)
# Out:
# LogisticRegression()

# %% [markdown]
# #predict the model

# %%
ypred = model.predict(xtest)

# %% [markdown]
# #Model Evaluation

# %% [markdown]
# Check the accuracy

# %%
accuracy = accuracy_score(ytest, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9605381165919282

# %% [markdown]
# Use confusion matrix

# %%
print(confusion_matrix(ytest, y_pred))
# Out:
# [[965   1]
#  [ 43 106]]

# %% [markdown]
# check Classification report

# %%
print(classification_report(ytest, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98       966
#            1       0.99      0.71      0.83       149
#
#     accuracy                           0.96      1115
#    macro avg       0.97      0.86      0.90      1115
# weighted avg       0.96      0.96      0.96      1115

# %% [markdown]
# #Real Message Test (demo)

# %%
msg = ["Free lottery winner claim now"]
print(model.predict(vec.transform(msg)))
# Out:
# [1]

# %%
msg = ["urgent you have won a week free membership"]

pred = model.predict(vec.transform(msg))

if pred[0] == 1:
    print("Spam")
else:
    print("Not Spam")
# Out:
# Spam
